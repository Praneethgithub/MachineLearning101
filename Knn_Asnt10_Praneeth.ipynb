# %% [markdown]
# <a href="https://colab.research.google.com/github/Praneethgithub/MachineLearning101/blob/main/Knn_Asnt10_Praneeth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline

# %%
df=pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.describe()
# Out:
#                RI          Na          Mg  ...          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  ...  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533  ...    0.175047    0.057009    2.780374
# std      0.003037    0.816604    1.442408  ...    0.497219    0.097439    2.103739
# min      1.511150   10.730000    0.000000  ...    0.000000    0.000000    1.000000
# 25%      1.516523   12.907500    2.115000  ...    0.000000    0.000000    1.000000
# 50%      1.517680   13.300000    3.480000  ...    0.000000    0.000000    2.000000
# 75%      1.519157   13.825000    3.600000  ...    0.000000    0.100000    3.000000
# max      1.533930   17.380000    4.490000  ...    3.150000    0.510000    7.000000
#
# [8 rows x 10 columns]

# %%
sns.set(style="whitegrid", font_scale=1.8)
plt.subplots(figsize = (15,8))
sns.countplot('Type',data=df).set_title('Count of Glass Types')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Count of Glass Types')

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
# from sklearn.decomposition import PCA

# pca_red = PCA(n_components=5)
# X_reduced = pca_red.fit_transform(X_var)

# %%
# X = X_reduced
# X

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size=0.30)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
import seaborn as sns

sns.pairplot(df,hue='Type')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
sns.pairplot(df[['RI','Na','Mg','Al','Si','Ca']], kind='reg')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
print(np.unique(y_train))
print(np.unique(y_test))
# Out:
# [1 2 3 5 6 7]
# [1 2 3 5 6 7]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1,metric='seuclidean')
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-328370988d70> in <module>()
#       2
#       3 knn = KNeighborsClassifier(n_neighbors=1,metric='seuclidean')
# ----> 4 knn.fit(X_train,y_train)
#       5 pred = knn.predict(X_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1149             self._y = self._y.ravel()
#    1150
# -> 1151         return self._fit(X)
#    1152
#    1153
#
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_base.py in _fit(self, X)
#     451             self._tree = BallTree(X, self.leaf_size,
#     452                                   metric=self.effective_metric_,
# --> 453                                   **self.effective_metric_params_)
#     454         elif self._fit_method == 'kd_tree':
#     455             self._tree = KDTree(X, self.leaf_size,
#
# ...
